# %% [markdown]
# # Introduction
#
# Today we will demonstrate how you can generate advertizing content for your inventory to boost sales. We'll do this taking advantage of Azure Cosmos DB for Mongo DB vCore's [vector similarity search](https://learn.microsoft.com/azure/cosmos-db/mongodb/vcore/vector-search) functionality. We will use OpenAI embeddings to generate vectors for inventory description which expected to vastly enhance its semantics. The vectors are then stored and indexed in the Mongo vCore Database. During the content generation for the advertisement time we will also vectorize the advertisement topic and find matching inventory itmes. We will then use retrival augmented generation (RAG) by sending to top matches to OpenAI to generate a catchy advertisement.

# %% [markdown]
# # Scenario
#
# 1. Shoe Retailer who wants to sell more shoes
# 2. Wants to run advertisement to capitalize on recent trends
# 2. Wants to use generate advertisement content using the inventory items that matches the trend

# %% [markdown]
# ## Azure OpenAI <a class="anchor" id="azureopenai"></a>
#
# Finally, let's setup our Azure OpenAI resource Currently, access to this service is granted only by application. You can apply for access to Azure OpenAI by completing the form at https://aka.ms/oai/access. Once you have access, complete the following steps:
#
# - Create an Azure OpenAI resource following this quickstart: https://learn.microsoft.com/azure/ai-services/openai/how-to/create-resource?pivots=web-portal
# - Deploy a `completions` and `embeddings` model
#     - For more information on `completions`, go here: https://learn.microsoft.com/azure/ai-services/openai/how-to/completions
#     - For more information on `embeddings`, go here: https://learn.microsoft.com/azure/ai-services/openai/how-to/embeddings
# - Copy the endpoint, key, deployment names for (embeddings model, completions model) into the config.json file.

# %% [markdown]
# ## Create an Azure Cosmos DB for MongoDB vCore resource<a class="anchor" id="cosmosdb"></a>
# Let's start by creating an Azure Cosmos DB for MongoDB vCore Resource following this quick start guide: https://learn.microsoft.com/en-us/azure/cosmos-db/mongodb/vcore/quickstart-portal
#
# Then copy the connection details (server, user, pwd) into the environment file.

# %% [markdown]
# # Preliminaries <a class="anchor" id="preliminaries"></a>
# First, let's start by installing the packages that we'll need later.

# %%
! pip install numpy
! pip install openai==1.2.3
#! pip install openai==0.28
! pip install pymongo
! pip install python-dotenv
! pip install azure-core
! pip install azure-cosmos
! pip install tenacity
! pip install gradio
# Out:
# Requirement already satisfied: numpy in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (1.24.3)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openai==1.2.3 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (1.2.3)
# Requirement already satisfied: anyio<4,>=3.5.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from openai==1.2.3) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from openai==1.2.3) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from openai==1.2.3) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from openai==1.2.3) (2.7.0)
# Requirement already satisfied: tqdm>4 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from openai==1.2.3) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.5 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from openai==1.2.3) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from anyio<4,>=3.5.0->openai==1.2.3) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from anyio<4,>=3.5.0->openai==1.2.3) (1.2.0)
# Requirement already satisfied: certifi in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai==1.2.3) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai==1.2.3) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.2.3) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.2.3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.2.3) (2.18.1)
# Requirement already satisfied: colorama in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from tqdm>4->openai==1.2.3) (0.4.6)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pymongo in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (4.6.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from pymongo) (2.6.1)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-dotenv in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (1.0.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: azure-core in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (1.30.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from azure-core) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from azure-core) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from azure-core) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core) (2023.5.7)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: azure-cosmos in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: azure-core>=1.25.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from azure-cosmos) (1.30.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from azure-cosmos) (4.11.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from azure-core>=1.25.1->azure-cosmos) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from azure-core>=1.25.1->azure-cosmos) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.25.1->azure-cosmos) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.25.1->azure-cosmos) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.25.1->azure-cosmos) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.25.1->azure-cosmos) (2023.5.7)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tenacity in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (8.2.2)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gradio in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (4.27.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (22.1.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (5.0.1)
# Requirement already satisfied: fastapi in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (0.110.2)
# Requirement already satisfied: ffmpy in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==0.15.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (0.15.1)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (0.22.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (1.24.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (3.9.15)
# Requirement already satisfied: packaging in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (2.7.0)
# Requirement already satisfied: pydub in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (0.4.1)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: urllib3~=2.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (2.2.1)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio) (0.23.2)
# Requirement already satisfied: fsspec in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio-client==0.15.1->gradio) (2024.3.1)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from gradio-client==0.15.1->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: anyio in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (3.5.0)
# Requirement already satisfied: certifi in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: idna in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (3.4)
# Requirement already satisfied: sniffio in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.9.0)
# Requirement already satisfied: requests in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.65.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2022.7)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (2.18.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.5.2)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from fastapi->gradio) (0.37.2)
# Requirement already satisfied: colorama in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\640240744\appdata\local\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Please use the example.env as a template to provide the necessary keys and endpoints in your own .env file.
# Make sure to modify the env_name accordingly.

# %%
import json
import time
import openai

from dotenv import dotenv_values
from openai import AzureOpenAI

# specify the name of the .env file name 
#env_name = "adgen.env" # following example.env template change to your own .env file name
env_name = "example.env" # following example.env template change to your own .env file name
config = dotenv_values(env_name)

openai.api_type = config['openai_api_type']
openai.api_key = config['openai_api_key']
openai.api_base = config['openai_api_endpoint']
openai.api_version = config['openai_api_version']

openai.api_type = "azure"
openai.api_key = "XXXXXXXXXXXXXXXXXXXXXXXXX"
openai.api_base = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX/"
openai.api_version = "2024-02-01"
print("api_type=",openai.api_type)
print("api_key=",openai.api_key)
print("endpoint=",openai.api_base)
print("version=",openai.api_version)

client = AzureOpenAI(
    api_key=openai.api_key,
    api_version=openai.api_version,
    azure_endpoint = openai.api_base
)

print("client=",client)
# Out:
# api_type= azure
# api_key= XXXXXXXXXXXXXXXXXXXXXXXXXXXX
# endpoint= XXXXXXXXXXXXXXXXXXXXXXXXXX
# version= 2024-02-01
# client= <openai.lib.azure.AzureOpenAI object at 0x0000014E47728D50>

# %% [markdown]
# # Create embeddings <a class="anchor" id="loaddata"></a>
# Here we'll load a sample dataset containing descriptions of Azure services. Then we'll user Azure OpenAI to create vector embeddings from this data.

# %%
from openai import AzureOpenAI
import openai
def generate_embeddings(text):
    '''
    Generate embeddings from string of text.
    This will be used to vectorize data and user input for interactions with Azure OpenAI.
    '''
    try:
      deploymentName = "text-embedding-ada-002"
      #deploymentName = "text-recommendation"
      #response = client.embeddings.create( input=text, model="text-embedding-ada-002")
      '''
      client = AzureOpenAI(
      api_key=openai.api_key,
      api_version=openai.api_version,
      azure_endpoint = openai.api_base
      )
      print(client)
      print(openai.api_key)
      print(openai.api_version)
      print(openai.api_base)
      '''
      response = client.embeddings.create(input=text,model=deploymentName)
      #embeddings = openai.Embedding.create(engine=deploymentName, input=text)
      #print(embeddings)
      print(response)
      embeddings = response.data[0].embedding
      #time.sleep(0.5) # rest period to avoid rate limiting on AOAI for free tier
      return embeddings
    except Exception as e:
      # Handle any exceptions that occurred during the request
      print(f"An error occurred: {e}")
      return None
 

embeddings = generate_embeddings("Shoes for San Francisco summer")
if embeddings is not None:
   print(embeddings)
# Out:
# CreateEmbeddingResponse(data=[Embedding(embedding=[0.013928048312664032, -0.018227633088827133, -0.002117219613865018, -0.028481490910053253, -0.0009161046473309398, 0.006358173675835133, -0.03551717475056648, 0.006937965750694275, 0.019374188035726547, -0.019608711823821068, 0.00758290383964777, -0.00019462134514469653, 0.006964024156332016, -0.008905352093279362, -0.0035178419202566147, -0.018318835645914078, 0.01792796514928341, 0.004856576211750507, 0.028716012835502625, -0.017849789932370186, -0.017458919435739517, 0.004286555573344231, 0.004788173828274012, -0.02371286042034626, -0.00694448035210371, -0.004768630024045706, 0.01878788135
081334114075, 0.016299333423376083, 0.011074687354266644, -0.0022035371512174606, 0.013211450539529324, 0.015726055949926376, -0.0185533594340086, 0.025797506794333458, -0.010442778468132019, -0.0038631116040050983, -0.008390704169869423, 0.010885766707360744, -0.0014136512763798237, 0.0015944292536005378, 0.02736099250614643, -0.012520911172032356, -0.013941077515482903, 0.014722819440066814, -0.015934521332383156, 0.038122981786727905, -0.018748793751001358, 0.017354685813188553, 0.017836760729551315, 0.025888711214065552, 0.0038305390626192093, -0.008898837491869926, -0.018944229930639267, -2.3131642592488788e-05, -0.0009144760551862419, -0.018540330231189728, 0.011283151805400848, 0.03095700964331627, 0.02112008072435856, 0.009341824799776077, 0.0057002 ...

# %% [markdown]
# # Connect and setup Cosmos DB for MongoDB vCore

# %% [markdown]
# ## Set up the connection

# %%
import pymongo

env_name = "example.env"
config = dotenv_values(env_name)

mongo_conn = config['mongo_vcore_connection_string']
mongo_client = pymongo.MongoClient(mongo_conn)

# %% [markdown]
# ##  Set up the DB and collection

# %%
DATABASE_NAME = "AdgenDatabase"
COLLECTION_NAME = "AdgenCollection"

mongo_client.drop_database(DATABASE_NAME)
db = mongo_client[DATABASE_NAME]
collection = db[COLLECTION_NAME]

if COLLECTION_NAME not in db.list_collection_names():
    # Creates a unsharded collection that uses the DBs shared throughput
    db.create_collection(COLLECTION_NAME)
    print("Created collection '{}'.\n".format(COLLECTION_NAME))
else:
    print("Using collection: '{}'.\n".format(COLLECTION_NAME))
# Out:
# Created collection 'AdgenCollection'.

# %% [markdown]
# ## Create the vector index

# %%
db.command({
  'createIndexes': COLLECTION_NAME,
  'indexes': [
    {
      'name': 'vectorSearchIndex',
      'key': {
        "contentVector": "cosmosSearch"
      },
      'cosmosSearchOptions': {
        'kind': 'vector-ivf',
        'numLists': 1,
        'similarity': 'COS',
        'dimensions': 1536
      }
    }
  ]
});

# %% [markdown]
# ## Upload data to the collection
# A simple `insert_many()` to insert our data in JSON format into the newly created DB and collection.

# %%
data_file = open(file="./data/shoes_with_vectors.json", mode="r") 
data = json.load(data_file)
data_file.close()

collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('6625fec1014b4a3663f87f7a'), ObjectId('6625fec1014b4a3663f87f7b'), ObjectId('6625fec1014b4a3663f87f7c'), ObjectId('6625fec1014b4a3663f87f7d'), ObjectId('6625fec1014b4a3663f87f7e'), ObjectId('6625fec1014b4a3663f87f7f'), ObjectId('6625fec1014b4a3663f87f80'), ObjectId('6625fec1014b4a3663f87f81'), ObjectId('6625fec1014b4a3663f87f82'), ObjectId('6625fec1014b4a3663f87f83'), ObjectId('6625fec1014b4a3663f87f84'), ObjectId('6625fec1014b4a3663f87f85'), ObjectId('6625fec1014b4a3663f87f86'), ObjectId('6625fec1014b4a3663f87f87'), ObjectId('6625fec1014b4a3663f87f88'), ObjectId('6625fec1014b4a3663f87f89'), ObjectId('6625fec1014b4a3663f87f8a'), ObjectId('6625fec1014b4a3663
4a3663f87fca'), ObjectId('6625fec1014b4a3663f87fcb'), ObjectId('6625fec1014b4a3663f87fcc'), ObjectId('6625fec1014b4a3663f87fcd'), ObjectId('6625fec1014b4a3663f87fce'), ObjectId('6625fec1014b4a3663f87fcf'), ObjectId('6625fec1014b4a3663f87fd0'), ObjectId('6625fec1014b4a3663f87fd1'), ObjectId('6625fec1014b4a3663f87fd2'), ObjectId('6625fec1014b4a3663f87fd3'), ObjectId('6625fec1014b4a3663f87fd4'), ObjectId('6625fec1014b4a3663f87fd5'), ObjectId('6625fec1014b4a3663f87fd6'), ObjectId('6625fec1014b4a3663f87fd7'), ObjectId('6625fec1014b4a3663f87fd8'), ObjectId('6625fec1014b4a3663f87fd9'), ObjectId('6625fec1014b4a3663f87fda'), ObjectId('6625fec1014b4a3663f87fdb'), ObjectId('6625fec1014b4a3663f87fdc'), ObjectId('6625fec1014b4a3663f87fdd'), ObjectId('6625fec1014b4a3663f87fde'), ObjectId('6625fec1014b4a3663f87fdf'), ObjectId('6625fec1014b4a3663f87fe0'), ObjectId('6625fec1014b4a3663f87fe1'), ObjectId('6625fec1014b4a3663f8 ...

# %% [markdown]
# # Vector Search in Cosmos DB for MongoDB vCore

# %%
# Function to assist with vector search
def vector_search(query, num_results=3):
    
    query_vector = generate_embeddings(query)

    embeddings_list = []
    pipeline = [
        {
            '$search': {
                "cosmosSearch": {
                    "vector": query_vector,
                    "numLists": 1,
                    "path": "contentVector",
                    "k": num_results
                },
                "returnStoredSource": True }},
        {'$project': { 'similarityScore': { '$meta': 'searchScore' }, 'document' : '$$ROOT' } }
    ]
    results = collection.aggregate(pipeline)
    return results

# %% [markdown]
# ## Perform vector search query

# %%
query = "Shoes for Seattle sweater weather"
results = vector_search(query, 3)

print("\nResults:\n")
for result in results: 
    print(result)
    print(f"Similarity Score: {result['similarityScore']}")  
    print(f"Title: {result['document']['name']}")  
    print(f"Price: {result['document']['price']}")  
    print(f"Material: {result['document']['material']}") 
    print(f"Image: {result['document']['img_url']}\n") 
    #print(f"purchase: {result['document']['purchase_url']}\n")
# Out:
# CreateEmbeddingResponse(data=[Embedding(embedding=[0.011651516892015934, -0.020172009244561195, -0.005559493321925402, -0.019222436472773552, -0.01238294504582882, 0.014423243701457977, -0.015488305129110813, -0.011272971518337727, 0.014487404376268387, -0.034543924033641815, -0.0010474175214767456, -0.004176837857812643, 0.004747864790260792, -0.01030415017157793, -0.007397686596959829, -0.029975708574056625, 0.02761460840702057, 0.012055727653205395, 0.02158353663980961, -0.03259345144033432, -0.015950258821249008, 0.013589159585535526, 0.029128793627023697, -0.01301813218742609, -0.005918791051954031, -0.021827345713973045, 0.01979988068342209, -0.031027939170598984, -0.003054032102227211, -0.013152869418263435, 0.028256211429834366, -0.012344448827207088, -0.02848718874156475, -0.015180335380136967, -0.0076414961367845535, -0.015424145385622978, -0.0023161880671977997, 0.007307862397283316, -0.011118986643850803, -0.0178879015147686, 0.009136
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt},
    ]

    response = client.chat.completions.create(
        model="gpt-35-turbo",
        messages=messages
    )
    
    return response.choices[0].message.content
    print("Here1")
def Generate_ad_image(ad_topic):
    daliClient = OpenAI(
        #api_key=config['dali_api_key']
        api_key="XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
    )

    image_prompt = f'''
        Generate a photorealistic image of an ad campaign for selling {ad_topic}. 
        The image should be clean, with the item being sold in the foreground with an easily identifiable landmark of the city in the background.
        The image should also try to depict the weather of the location for the time of the year mentioned.
        The image should not have any generated text overlay.
    '''

    response = daliClient.images.generate(
        model="dall-e-3",
        prompt= image_prompt,
        size="1024x1024",
        quality="standard",
        n=1,
        )

    return response.data[0].url
    print("Here2")
def render_html_page(ad_topic):

    # Find the matching shoes from the inventory
    results = vector_search(ad_topic, 4)

    ad_header = generate_ad_title(ad_topic)
    ad_image_url = Generate_ad_image(ad_topic)


    with open('./data/ad-start.html', 'r', encoding='utf-8') as html_file:
        html_content = html_file.read()

    html_content += f'''<header>
            <h2>{ad_header}</h1>
        </header>'''    

    html_content += f'''
            <section class="ad">
            <img src="{ad_image_url}" alt="Base Ad Image" class="ad-image">
        </section>'''

    for result in results: 
        html_content += f''' 
        <section class="product">
            <img src="{result['document']['img_url']}" alt="{result['document']['name']}" class="product-image">
            <div class="product-details">
                <h3 class="product-title" color="gray">{result['document']['name']}</h2>
                <p class="product-price">{"$"+str(result['document']['price'])}</p>
                <p class="product-description">{result['document']['description']}</p>
                <a href="#" class="buy-now-button">Buy Now</a>
            </div>
        </section>
        '''

    html_content += '''</article>
                    </body>
                    </html>'''

    return html_content

# %% [markdown]
# # Putting it all together

# %%
import gradio as gr

css = """
    button { background-color: purple; color: read; }
    <style>
    </style>
"""

with gr.Blocks(css=css, theme=gr.themes.Default(spacing_size=gr.themes.sizes.spacing_sm, radius_size="none")) as demo:
    subject = gr.Textbox(placeholder="subject", label="Ad keywords")
    btn = gr.Button("Generate Ad")
    output_html = gr.HTML(label="Generated Ad HTML")

    btn.click(render_html_page, [subject], output_html)

    btn = gr.Button("Copy HTML")

if __name__ == "__main__":
    demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7863
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# CreateEmbeddingResponse(data=[Embedding(embedding=[0.011651516892015934, -0.020172009244561195, -0.005559493321925402, -0.019222436472773552, -0.01238294504582882, 0.014423243701457977, -0.015488305129110813, -0.011272971518337727, 0.014487404376268387, -0.034543924033641815, -0.0010474175214767456, -0.004176837857812643, 0.004747864790260792, -0.01030415017157793, -0.007397686596959829, -0.029975708574056625, 0.02761460840702057, 0.012055727653205395, 0.02158353663980961, -0.03259345144033432, -0.015950258821249008, 0.013589159585535526, 0.029128793627023697, -0.01301813218742609, -0.005918791051954031, -0.021827345713973045, 0.01979988068342209, -0.031027939170598984, -0.003054032102227211, -0.013152869